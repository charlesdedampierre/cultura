# %%
import sqlite3
import pandas as pd
import sys
import plotly.graph_objects as go

sys.path.append('../')

from dotenv import load_dotenv

load_dotenv()
import os
DB_PATH = os.getenv("DB_PATH")



conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# %%
# Load individuals Main Informations
individuals = pd.read_sql_query("SELECT * FROM individuals_kept", conn)

# %%
# Load identifiers meta-data
df_identifiers = pd.read_sql_query("SELECT * FROM identifiers", conn)
df_identifiers['country_name'][df_identifiers['country_name'].isna()]=''
df_identifiers['identifier_name'] = df_identifiers.apply(lambda x : x['identifier_name'] + ' ('  + x['country_name'] + ')' if x['country_name']!='' else x['identifier_name'], axis=1)
df_identifiers = df_identifiers.drop(['country_wikidata_id', 'count_records', 'identifier_url'], axis=1).drop_duplicates()
df_identifiers = df_identifiers.drop(['country_name', 'identifier_name_country'], axis=1).drop_duplicates()
# Out:
# /var/folders/lx/9b13r6ln63jb54_3xlf9b_380000gn/T/ipykernel_65208/4189010349.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_identifiers['country_name'][df_identifiers['country_name'].isna()]=''

# %%
# Load infirmation about individuals and identifiers
df_ind_identifiers = pd.read_sql_query("SELECT * FROM individual_identifiers", conn)
df_ind_identifiers = df_ind_identifiers.drop('identifier_name', axis=1)
df_ind_identifiers = pd.merge(df_ind_identifiers, df_identifiers, on = 'identifiers_wikidata_id', how = 'left')

# Freebase is now mixed with Google ID
df_ind_identifiers['identifier_name'][df_ind_identifiers['identifier_name']=='Freebase ID'] = 'Google Knowledge Graph ID'
df_ind_identifiers['identifiers_wikidata_id'][df_ind_identifiers['identifiers_wikidata_id']=='P646'] = 'P2671'

# Mix the two GND
df_ind_identifiers['identifier_name'][df_ind_identifiers['identifier_name']=='Deutsche Biographie (GND) ID (Germany)'] = 'GND ID (Germany)'
df_ind_identifiers['identifiers_wikidata_id'][df_ind_identifiers['identifiers_wikidata_id']=='P7902'] = 'P227'

# Clean wrong objects
df_ind_identifiers = df_ind_identifiers[~df_ind_identifiers['individual_name'].str.contains('Painter')]

# Remove superceded
df_ind_identifiers = df_ind_identifiers[~df_ind_identifiers['identifier_name'].str.contains('superceded')]
df_ind_identifiers = df_ind_identifiers[~df_ind_identifiers['identifier_name'].str.contains('obsolete')]

# Drop duplicated after mergeing GND and Freebase
df_ind_identifiers = df_ind_identifiers.drop_duplicates()

# %%
df_ind_identifiers
# Out:
#         individual_wikidata_id              individual_name  \
# 0                    Q46995803          Johann Michael Vogt
# 1                    Q46995803          Johann Michael Vogt
# 2                    Q46995803          Johann Michael Vogt
# 3                    Q46995803          Johann Michael Vogt
# 4                     Q4684802               Adriaen Matham
# ...                        ...                          ...
# 3003267              Q60214671             Joseph Schneller
# 3003268              Q97571271  Antonio González de Cedillo
# 3003269              Q97571271  Antonio González de Cedillo
# 3003270              Q97571271  Antonio González de Cedillo
# 3003271              Q97571271  Antonio González de Cedillo
#
#         identifiers_wikidata_id  \
# 0                          P214
# 1                          P227
# 2                         P2671
# 3                         P3413
# 4                          P213
# ...                         ...
# 3003267                   P9223
# 3003268                    P245
# 3003269                   P2843
# 3003270                   P7848
# 3003271                   P8572
#
#                                            identifier_name
# 0                                                  VIAF ID
# 1                                         GND ID (Germany)
# 2                                Google Knowledge Graph ID
# 3              Leopoldina member ID (superseded) (Germany)
# 4                                                     ISNI
# ...                                                    ...
# 3003267                     Provenio UUID (Czech Republic)
# 3003268  Union List of Artist Names ID (United States o...
# 3003269                                         Benezit ID
# 3003270         Frick Art Reference Library Artist File ID
# 3003271  Spanish Artists from the Fourth to the Twentie...
#
# [2776067 rows x 4 columns]

# %%
len(set(df_ind_identifiers.identifiers_wikidata_id))
# Out:
# 1672

# %%
df_final = pd.merge(df_ind_identifiers, individuals, on = 'individual_wikidata_id')
df_stats = df_final[['individual_wikidata_id', 'identifier_name']].drop_duplicates()

# %%
len(set(df_stats['identifier_name']))
# Out:
# 1652

# %%
df_stats
# Out:
#         individual_wikidata_id  \
# 0                    Q46995803
# 1                    Q46995803
# 2                    Q46995803
# 3                    Q46995803
# 4                     Q4684802
# ...                        ...
# 2525790              Q60214671
# 2525791              Q97571271
# 2525792              Q97571271
# 2525793              Q97571271
# 2525794              Q97571271
#
#                                            identifier_name
# 0                                                  VIAF ID
# 1                                         GND ID (Germany)
# 2                                Google Knowledge Graph ID
# 3              Leopoldina member ID (superseded) (Germany)
# 4                                                     ISNI
# ...                                                    ...
# 2525790                     Provenio UUID (Czech Republic)
# 2525791  Union List of Artist Names ID (United States o...
# 2525792                                         Benezit ID
# 2525793         Frick Art Reference Library Artist File ID
# 2525794  Spanish Artists from the Fourth to the Twentie...
#
# [2525795 rows x 2 columns]

# %%
len(list(set(df_stats.identifier_name)))
# Out:
# 1652

# %%
# Group by 'identifier_name' and calculate the count and percentage
grouped = df_stats.groupby('identifier_name').size().reset_index(name='count')
grouped = grouped.sort_values('count', ascending=False).reset_index(drop=True)
grouped['percent'] = round(grouped['count']/len(individuals)*100, 1)
grouped.columns = ['Catalog', 'N Individuals', '%']

grouped['Catalog'] = grouped['Catalog'].str.replace('United States of America', 'US')
grouped.head(20)
# Out:
#                                               Catalog  N Individuals     %
# 0                                             VIAF ID         139198  80.5
# 1                           Google Knowledge Graph ID         127136  73.5
# 2                                    GND ID (Germany)         100841  58.3
# 3                                                ISNI          99399  57.5
# 4                                   CERL Thesaurus ID          78983  45.7
# 5               Library of Congress authority ID (US)          76335  44.1
# 6                                   IdRef ID (France)          53717  31.0
# 7   Nationale Thesaurus voor Auteurs ID (Netherlands)          51121  29.5
# 8        Bibliothèque nationale de France ID (France)          50378  29.1
# 9                                             FAST ID          45324  26.2
# 10                               Open Library ID (US)          43221  25.0
# 11                                  NUKAT ID (Poland)          40323  23.3
# 12                                 PLWABN ID (Poland)          34637  20.0
# 13         National Library of Israel J9U ID (Israel)          32987  19.1
# 14                       NKCR AUT ID (Czech Republic)          32778  18.9
# 15                 Union List of Artist Names ID (US)          31294  18.1
# 16                        RKDartists ID (Netherlands)          29509  17.1
# 17                                         Benezit ID          29275  16.9
# 18                                         Prabook ID          27883  16.1
# 19             Vatican Library VcBA ID (Vatican City)          27065  15.6

# %%
ind_unseen = pd.read_csv('unseen_species_model/unseen_species_model_bayesian.csv')
df_stats_filtered = df_stats[df_stats['individual_wikidata_id'].isin(list(set(ind_unseen['individual_wikidata_id'])))]
print(len(set(df_stats_filtered['identifier_name'])))


df_identifiers = pd.read_sql_query("SELECT * FROM identifiers", conn)
df_identifiers['country_name'][df_identifiers['country_name'].isna()]=''
df_identifiers['identifier_name'] = df_identifiers.apply(lambda x : x['identifier_name'] + ' ('  + x['country_name'] + ')' if x['country_name']!='' else x['identifier_name'], axis=1)


# Load infirmation about individuals and identifiers
df_ind_identifiers = pd.read_sql_query("SELECT * FROM individual_identifiers", conn)
df_ind_identifiers = df_ind_identifiers.drop('identifier_name', axis=1)
df_ind_identifiers = pd.merge(df_ind_identifiers, df_identifiers, on = 'identifiers_wikidata_id', how = 'left')
df_ind_identifiers
# Out:
# 1360
# /var/folders/lx/9b13r6ln63jb54_3xlf9b_380000gn/T/ipykernel_65208/4080614744.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_identifiers['country_name'][df_identifiers['country_name'].isna()]=''
#         individual_wikidata_id              individual_name  \
# 0                    Q46995803          Johann Michael Vogt
# 1                    Q46995803          Johann Michael Vogt
# 2                    Q46995803          Johann Michael Vogt
# 3                    Q46995803          Johann Michael Vogt
# 4                     Q4684802               Adriaen Matham
# ...                        ...                          ...
# 3003267              Q60214671             Joseph Schneller
# 3003268              Q97571271  Antonio González de Cedillo
# 3003269              Q97571271  Antonio González de Cedillo
# 3003270              Q97571271  Antonio González de Cedillo
# 3003271              Q97571271  Antonio González de Cedillo
#
#         identifiers_wikidata_id  \
# 0                          P214
# 1                          P227
# 2                         P2671
# 3                         P3413
# 4                          P213
# ...                         ...
# 3003267                   P9223
# 3003268                    P245
# 3003269                   P2843
# 3003270                   P7848
# 3003271                   P8572
#
#                                            identifier_name  \
# 0                                                  VIAF ID
# 1                                         GND ID (Germany)
# 2                                Google Knowledge Graph ID
# 3              Leopoldina member ID (superseded) (Germany)
# 4                                                     ISNI
# ...                                                    ...
# 3003267                     Provenio UUID (Czech Republic)
# 3003268  Union List of Artist Names ID (United States o...
# 3003269                                         Benezit ID
# 3003270         Frick Art Reference Library Artist File ID
# 3003271  Spanish Artists from the Fourth to the Twentie...
#
#         country_wikidata_id              country_name  count_records  \
# 0                      None                               33656281.0
# 1                      Q183                   Germany      9217240.0
# 2                      None                                      NaN
# 3                      Q183                   Germany            NaN
# 4                      None                               11020000.0
# ...                     ...                       ...            ...
# 3003267                Q213            Czech Republic        48290.0
# 3003268                 Q30  United States of America       356156.0
# 3003269                None                                      NaN
# 3003270                None                                      NaN
# 3003271                 Q29                     Spain         5185.0
#
#                                             identifier_url  \
# 0                                         https://viaf.org
# 1                                    https://portal.dnb.de
# 2           https://developers.google.com/knowledge-graph/
# 3        http://www.leopoldina.org/de/mitglieder/mitgli...
# 4                                                     None
# ...                                                    ...
# 3003267                               https://provenio.net
# 3003268                                               None
# 3003269           https://www.oxfordartonline.com/benezit/
# 3003270                          https://library.frick.org
# 3003271  https://research.frick.org/spanish/advancedSearch
#
#                                    identifier_name_country
# 0                                                  VIAF ID
# 1                                         GND ID (Germany)
# 2                                Google Knowledge Graph ID
# 3              Leopoldina member ID (superseded) (Germany)
# 4                                                     ISNI
# ...                                                    ...
# 3003267                     Provenio UUID (Czech Republic)
# 3003268  Union List of Artist Names ID (United States o...
# 3003269                                         Benezit ID
# 3003270         Frick Art Reference Library Artist File ID
# 3003271  Spanish Artists from the Fourth to the Twentie...
#
# [3003272 rows x 9 columns]

# %%
df_stats_filtered = pd.merge(df_stats_filtered, df_identifiers, on = 'identifier_name')
df_stats_filtered
# Out:
#         individual_wikidata_id  \
# 0                    Q46995803
# 1                    Q56599708
# 2                    Q10377783
# 3                     Q1319090
# 4                     Q2080951
# ...                        ...
# 1396773              Q19325138
# 1396774              Q27500953
# 1396775              Q60515669
# 1396776              Q18672131
# 1396777             Q107452623
#
#                                            identifier_name  \
# 0                                                  VIAF ID
# 1                                                  VIAF ID
# 2                                                  VIAF ID
# 3                                                  VIAF ID
# 4                                                  VIAF ID
# ...                                                    ...
# 1396773  Whitney Museum of American Art artist ID (Unit...
# 1396774  Irish playography person ID (Republic of Ireland)
# 1396775  South Carolina Encyclopedia ID (United States ...
# 1396776                         Film.ru person ID (Russia)
# 1396777                           CulturaItalia ID (Italy)
#
#         identifiers_wikidata_id country_wikidata_id              country_name  \
# 0                          P214                None
# 1                          P214                None
# 2                          P214                None
# 3                          P214                None
# 4                          P214                None
# ...                         ...                 ...                       ...
# 1396773                   P6714                 Q30  United States of America
# 1396774                   P7934                 Q27       Republic of Ireland
# 1396775                   P7690                 Q30  United States of America
# 1396776                  P10302                Q159                    Russia
# 1396777                   P1949                 Q38                     Italy
#
#          count_records                      identifier_url  \
# 0           33656281.0                    https://viaf.org
# 1           33656281.0                    https://viaf.org
# 2           33656281.0                    https://viaf.org
# 3           33656281.0                    https://viaf.org
# 4           33656281.0                    https://viaf.org
# ...                ...                                 ...
# 1396773         3533.0         https://whitney.org/artists
# 1396774            NaN    http://www.irishplayography.com/
# 1396775            NaN  http://www.scencyclopedia.org/sce/
# 1396776      1770332.0                     https://film.ru
# 1396777            NaN                                None
#
#                                    identifier_name_country
# 0                                                  VIAF ID
# 1                                                  VIAF ID
# 2                                                  VIAF ID
# 3                                                  VIAF ID
# 4                                                  VIAF ID
# ...                                                    ...
# 1396773  Whitney Museum of American Art artist ID (Unit...
# 1396774  Irish playography person ID (Republic of Ireland)
# 1396775  South Carolina Encyclopedia ID (United States ...
# 1396776                         Film.ru person ID (Russia)
# 1396777                           CulturaItalia ID (Italy)
#
# [1396778 rows x 8 columns]

# %%
df_stats_filtered['country_name'].nunique()
# Out:
# 71

# %%
# Out:
#      identifiers_wikidata_id  \
# 0                       P212
# 1                       P213
# 2                       P214
# 3                       P218
# 4                       P219
# ...                      ...
# 8017                  P11281
# 8018                  P11282
# 8019                  P11283
# 8020                  P11284
# 8021                  P11285
#
#                                         identifier_name country_wikidata_id  \
# 0                                               ISBN-13                None
# 1                                                  ISNI                None
# 2                                               VIAF ID                None
# 3                                        ISO 639-1 code                None
# 4                                        ISO 639-2 code                None
# ...                                                 ...                 ...
# 8017  Biographical Dictionary of the Australian Sena...                Q408
# 8018                      Tanzania Parliament member ID                Q924
# 8019                                            JCDb ID                 Q17
# 8020  Dictionnaire de l'Académie française ID (1st e...                Q142
# 8021  Dictionnaire de l'Académie française ID (2nd e...                Q142
#
#      country_name  count_records                         identifier_url  \
# 0            None            NaN                                   None
# 1            None     11020000.0                                   None
# 2            None     33656281.0                       https://viaf.org
# 3            None          184.0                                   None
# 4            None          486.0                                   None
# ...           ...            ...                                    ...
# 8017    Australia          600.0       https://biography.senate.gov.au/
# 8018     Tanzania          618.0  https://www.parliament.go.tz/mps-list
# 8019        Japan        49095.0     https://www.japanese-cinema-db.jp/
# 8020       France            NaN                                   None
# 8021       France            NaN                                   None
#
#                                 identifier_name_country
# 0                                               ISBN-13
# 1                                                  ISNI
# 2                                               VIAF ID
# 3                                        ISO 639-1 code
# 4                                        ISO 639-2 code
# ...                                                 ...
# 8017  Biographical Dictionary of the Australian Sena...
# 8018           Tanzania Parliament member ID (Tanzania)
# 8019                                    JCDb ID (Japan)
# 8020  Dictionnaire de l'Académie française ID (1st e...
# 8021  Dictionnaire de l'Académie française ID (2nd e...
#
# [8022 rows x 7 columns]
